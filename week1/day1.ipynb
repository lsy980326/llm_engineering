# %% [markdown]
# # 첫 번째 실습
# ### 이 섹션을 꼭 읽어주세요. 내용이 길더라도 여러분의 준비를 위해 매우 가치 있는 내용이며, 중요한 사항들입니다.
#
# ### 또한, [README.md](../README.md)를 반드시 읽어보세요! 업데이트된 영상에 대한 자세한 정보는 README와 [보라색으로 표시된 강의 리소스 상단](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)에서 확인하실 수 있습니다.
#
# ## 여러분의 첫 번째 프론티어 LLM 프로젝트
#
# 이 코스가 끝날 때쯤, 여러분은 비즈니스 문제를 해결하기 위해 7개의 에이전트가 협업하는 자율형 에이전트 AI 솔루션을 구축하게 될 것입니다. 모든 것은 때가 있는 법이죠! 우선은 작은 것부터 시작해 보겠습니다...
#
# 우리의 목표는 새로운 종류의 웹 브라우저를 코딩하는 것입니다. URL을 입력하면 요약본을 응답으로 돌려주는, 인터넷판 '리더스 다이제스트(요약본)'를 만드는 것이죠!!
#
# 시작하기 전에 README에 링크된 설정을 모두 완료해야 합니다.
#
# ### "노트북"(Labs 또는 Jupyter Lab이라고도 함) 사용이 처음이신 분들께
#
# 데이터 과학 실험의 멋진 세계에 오신 것을 환영합니다! 이 텍스트 바로 아래에 있는 코드 셀과 같이 코드가 포함된 각 "셀"을 클릭하고 **Shift+Return**을 눌러 해당 셀을 실행하기만 하면 됩니다. 맨 위부터 순서대로 모든 셀을 실행해야 합니다.
#
# 모든 가이드는 [Guides 폴더](../guides/01_intro.ipynb)에서 확인하실 수 있습니다.
#
# ## 제가 도와드리겠습니다
#
# 문제가 발생하면 언제든지 연락해 주세요.
# 플랫폼을 통해 문의하시거나, ed@edwarddonner.com으로 메일을 보내주시거나, 연결을 원하신다면 [LinkedIn](https://www.linkedin.com/in/eddonner/) (연결하는 것을 정말 좋아합니다!)으로 연락해 주세요.
# 그리고 저에게도 새로운 시도입니다만, X(트위터) [@edwarddonner](https://x.com/edwarddonner)도 시작해 보려고 합니다. X를 하신다면 어떻게 하는 건지 저에게 좀 알려주세요 😂
#
# ## 추가 문제 해결
#
# 일반적인 문제를 진단하고 해결하려면 setup 폴더의 [troubleshooting](../setup/troubleshooting.ipynb) 노트북을 참조하세요. 노트북 맨 끝에는 유용한 디버깅 정보가 담긴 진단 스크립트가 있습니다.
#
# ## 이미 익숙한 내용인가요?
#
# 오늘 다루는 내용이 이미 편안하게 느껴지더라도 조금만 참아주세요. 처음 몇 개의 실습은 빠르게 넘어가셔도 좋습니다. 주차가 진행될수록 훨씬 더 심도 있는 내용을 다룰 예정입니다. 궁극적으로 우리는 OpenAI와 경쟁할 수 있도록 우리만의 LLM을 미세 조정(Fine-tune)하게 될 것입니다!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">필독 - 중요한 참고 사항</h2>
#             <span style="color:#900;">제가 여러분과 협력하는 방식은 여러분이 수강했던 다른 강의와 다를 수 있습니다. 저는 여러분이 지켜보는 동안 코드를 직접 타이핑하는 것을 선호하지 않습니다. 대신, 이와 같은 Jupyter Lab을 실행하며 상황이 어떻게 돌아가는지에 대한 직관을 전달해 드립니다. 제 제안은, 강의를 시청한 <b>후에</b> 직접 주의 깊게 실행해 보는 것입니다. 출력문(print)을 추가해 무엇이 일어나는지 이해해 보고, 자신만의 변형된 코드를 만들어 보세요. GitHub 계정이 있다면 이를 활용해 여러분의 작업물을 뽐내보세요. 이는 필수적인 연습일 뿐만 아니라, 미래의 고객이나 고용주를 포함한 타인에게 여러분의 기술을 증명하는 방법이 됩니다...</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">이 코드는 살아있는 리소스입니다 - 제 이메일을 확인해 주세요</h2>
#             <span style="color:#f71;">저는 정기적으로 코드 업데이트를 푸시합니다. 질문이 들어오면 더 많은 예시나 개선된 설명을 추가합니다. 그 결과, 아래 코드가 영상과 완전히 일치하지 않을 수도 있습니다. 영상의 모든 내용은 여기에 포함되어 있으며, 더 나은 설명과 DeepSeek 같은 새로운 모델도 추가했습니다. 이 실습 자료를 인터랙티브한 책이라고 생각하세요.<br/><br/>
#                 강의와 관련된 중요한 업데이트가 있을 때마다 정기적으로 이메일을 보내려고 노력합니다. Udemy 왼쪽 사이드바의 '공지사항' 섹션에서 확인하실 수 있습니다. 또한 Udemy의 알림 설정을 통해 제 이메일을 받도록 선택할 수도 있습니다. 여러분의 편지함을 존중하며 항상 가치 있는 정보를 전달하기 위해 노력하겠습니다!
#             </span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">이 연습들의 비즈니스 가치</h2>
#             <span style="color:#181;">마지막 생각입니다. 이 노트북들을 교육적으로 설계함과 동시에 즐거움도 느낄 수 있도록 노력했습니다. LLM이 농담을 주고받거나 서로 논쟁하게 하는 등 재미있는 일들을 해볼 것입니다. 하지만 근본적으로 제 목표는 여러분이 비즈니스에 적용할 수 있는 기술을 가르치는 것입니다. 진행하면서 비즈니스적 시사점을 설명해 드릴 테니, 모델과 기술에 대한 경험을 쌓으면서 오늘 당장 업무에 적용할 수 있는 방법을 고민해 보세요. 더 논의하고 싶거나 아이디어를 나누고 싶다면 언제든지 연락해 주세요.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 필요 시, Cursor 확장 프로그램(Extensions) 설치
#
# 1. **View(보기)** 메뉴에서 **Extensions(확장)**를 선택합니다.
# 2. **Python**을 검색합니다.
# 3. **"ms-python"**에서 제작한 **"Python"**을 찾아 설치되지 않았다면 **Install(설치)**을 클릭합니다.
# 4. **Jupyter**를 검색합니다.
# 5. **"ms-toolsai"**에서 제작한 **"Jupyter"**를 찾아 설치되지 않았다면 **Install(설치)**을 클릭합니다.
#
# ---
#
# ### 다음으로 커널(Kernel) 선택
#
# 1. 우측 상단의 **"Select Kernel(커널 선택)"**을 클릭합니다.
# 2. **"Python Environments...(Python 환경...)"**를 선택합니다.
# 3. **`.venv (Python 3.12.x) .venv/bin/python`**과 같은 형식의 항목을 선택합니다. 이 항목은 **"Recommended(권장됨)"**라고 표시되어 있으며 옆에 큰 별 아이콘이 있어야 합니다.
#
# 이 과정에서 문제가 발생하나요? 그렇다면 **troubleshooting(문제 해결)** 노트북을 확인해 주세요.
#
# ### 참고: 새로운 노트북을 열 때마다 커널을 설정해야 합니다.

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # OpenAI (또는 Ollama) 연결하기
#
# 다음 셀은 `.env` 파일에 저장된 환경 변수를 불러오고 OpenAI에 연결하는 단계입니다.
#
# 유료 API 대신 무료인 **Ollama**를 사용하고 싶으시다면, README의 "Free Alternative to Paid APIs" 섹션을 참조해 주세요. 방법이 어려우시다면 솔루션 폴더에 전체 해결 코드(`day1_with_ollama.ipynb`)가 준비되어 있습니다.
#
# ## 문제 발생 시 해결 방법(Troubleshooting):
#
# **"Name Error"**가 발생한다면, 맨 위에서부터 모든 셀을 순서대로 실행하셨나요? 'Python Foundations' 가이드를 확인하시면 Name Error를 찾고 수정하는 가장 확실한 방법을 배우실 수 있습니다.
#
# 문제가 해결되지 않는다면, [troubleshooting](../setup/troubleshooting.ipynb) 노트북으로 이동하여 근본 원인을 파악하고 수정하는 단계별 코드를 실행해 보세요!
#
# 그래도 안 된다면 저에게 연락해 주세요! 메시지를 보내시거나 ed@edwarddonner.com으로 메일을 주시면 함께 해결해 보겠습니다.
#
# **API 비용**이 걱정되시나요? README에 적어둔 노트를 확인해 보세요. 비용은 매우 적게 발생할 것이며, 모든 단계에서 이를 제어할 수 있습니다. 또한 2일 차에 다룰 무료 대안인 Ollama를 사용할 수도 있습니다.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # 시작에 앞서, 맛보기로 최신 프론티어(Frontier) 모델을 신속하게 호출해 봅시다!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you. I’m ChatGPT, an AI assistant. I can help with questions, explanations, writing or editing, planning, coding, brainstorming, or just chatting.\n\nWhat would you like to do today? If you’re not sure, I can share a quick fun fact or we can start with a simple task.'

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# ...

# %% [markdown]
# ## 프롬프트의 종류
#
# 이미 알고 계실 수도 있지만, 모르셨더라도 금방 익숙해지실 내용입니다!
#
# GPT와 같은 모델들은 특정 방식으로 지시를 받도록 훈련되었습니다.
#
# 모델은 다음과 같은 구성을 기대합니다:
#
# **시스템 프롬프트 (System prompt):** 모델이 수행해야 할 작업이 무엇인지, 그리고 어떤 말투(톤)를 사용해야 하는지 알려주는 지침입니다.
#
# **사용자 프롬프트 (User prompt):** 모델이 응답해야 할 대화의 시작점(사용자의 질문이나 요청)입니다.

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
All answers will be in Korean.
"""


# # 시스템 프롬프트 정의 - 나중에 마지막 문장을 '스페인어 마크다운으로 응답해줘' 등으로 변경하며 실험해 보세요.

# system_prompt = """
# 당신은 웹사이트의 내용을 분석하여 짧고, 비꼬는 듯하며, 유머러스한 요약을 제공하는 까칠한 어시스턴트입니다.
# 내비게이션(메뉴)과 관련된 텍스트는 무시하세요.
# 마크다운 형식으로 응답하세요. 마크다운을 코드 블록으로 감싸지 말고, 마크다운 내용만 응답하세요.
# 모든 답변은 한국어로 작성해야 합니다.
# """
# Out:
# '\n# 시스템 프롬프트 정의 - 나중에 마지막 문장을 \'스페인어 마크다운으로 응답해줘\' 등으로 변경하며 실험해 보세요.\n\nsystem_prompt = """\n당신은 웹사이트의 내용을 분석하여 짧고, 비꼬는 듯하며, 유머러스한 요약을 제공하는 까칠한 어시스턴트입니다.\n내비게이션(메뉴)과 관련된 텍스트는 무시하세요.\n마크다운 형식으로 응답하세요. 마크다운을 코드 블록으로 감싸지 말고, 마크다운 내용만 응답하세요.\n모든 답변은 한국어로 작성해야 합니다.\n"""\n'

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.
All answers will be in Korean.
"""

# # 사용자 프롬프트 정의

# user_prompt_prefix = """
# 여기 웹사이트의 콘텐츠가 있습니다.
# 이 웹사이트의 내용을 짧게 요약해 주세요.
# 뉴스나 공지사항이 포함되어 있다면 그것들도 함께 요약해 주세요.
# 모든 답변은 한국어로 작성해야 합니다.
# """

# %% [markdown]
# ## 메시지 (Messages)
#
# OpenAI의 API는 메시지를 특정 구조로 전달받기를 기대합니다.
# 다른 많은 API들도 이와 동일한 구조를 공유하고 있습니다:
#
# ```python
# [
#     {"role": "system", "content": "시스템 메시지가 여기에 들어갑니다"},
#     {"role": "user", "content": "사용자 메시지가 여기에 들어갑니다"}
# ]
# ```
# 미리 맛보기를 드리자면, 다음 두 셀에서는 아주 간단한 호출을 진행할 예정입니다. 아직은 '강력한 GPT'의 능력을 한계까지 시험하지는 않을 거예요!
#
# ---
# **💡 설명:** * **role**: 메시지를 보내는 주체(시스템 혹은 사용자)를 정의합니다.
# * **content**: 실제 대화 내용이 들어가는 곳입니다.
#
# 이제 이 구조를 활용해 첫 번째 API 호출을 시작해 보시겠어요? 다음 코드 셀에서 `Shift + Enter`를 눌러 실행해 보세요!

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# '2 + 2 equals 4.'

# %% [markdown]
# ## 이제 함수를 사용해서, GPT-4o-mini를 위한 유용한 메시지 구조를 만들어 봅시다.

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\nAll answers will be in Korean.\n'},
#  {'role': 'user',
# ...

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Edward Donner 웹사이트 요약 – AI 덕후의 놀이터\n\n여기 Ed라는 남자가 자신을 소개하면서, AI 특히 거대한 언어 모델(LLM)에 대한 사랑과 집착을 뽐내는 중. 자신이 만든 Udemy 강좌가 세계 190개국에서 40만명 넘게 신청한 모양인데, 놀랍게도 그는 아직도 ‘초보 아마추어 전자음악 제작자’이다.  \n\n주요 컨텐츠는  \n- AI 커리큘럼 (Ed가 만든 베스트셀러 강의 모음)  \n- 프로페셔널 AI 엔지니어 되기 노하우  \n- Connect Four 게임과 ‘Outsmart’라는 LLM끼리 외교와 속임수 배틀을 벌이는 아레나 (LLM 싸움 구경은 덤)  \n\n최근 소식도 짤막한데, AI 코더부터 MLOps, AI 라이브 이벤트 등 AI 관련 신작과 소식들을 2025-2026년 걸쳐 꾸준히 올리고 있음.\n\n결론:  \n뭔가 복잡한 AI 덕질과 강의가 필요하다면 여기 오시라. 아, 그리고 뉴스레터 구독하면 Ed가 친구 잃고 혼자 떠드는 LLM 이야기 귀중하게 받을 수 있다.  \n짧게, AI 덕후들의 천국!'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # 에드워드 도너 웹사이트 요약
#
# 이분, 에드(Ed)는 코드 쓰고 LLM(대형 언어 모델) 갖고 놀기를 좋아하는 AI 덕후. 전직 AI 스타트업 CEO에 현재는 Nebula.io CTO로, '사람들이 자기 잠재력 발견하고 삶의 이유를 찾게 돕는 AI'를 연구 중임.
#
# 친구들이 강제로 만든 Udemy AI 코스는 전 세계 190개국에서 40만 명이나 듣는 대박 난리. 코딩과 AI 엔지니어링 제대로 배우고 싶으면 커리큘럼 구경해보라는 친절한 안내까지.
#
# 사이트에는 LLM 대결하는 ‘Outsmart’ 같은 재미난 프로젝트도 있고, 최신 AI 소식(2025~2026년)도 슬쩍훔쳐볼 수 있음. 에드랑 연락하고 뉴스레터 구독도 가능하니 AI 덕질할 준비됐으면 얼른 가입하셈!

# %% [markdown]
# # 더 많은 웹사이트들을 시도해 봅시다
#
# 이 방식은 아주 단순한 접근법으로 스크래핑이 가능한 웹사이트에서만 작동한다는 점에 유의하세요.
#
# React 앱처럼 자바스크립트로 렌더링되는 웹사이트들은 내용이 나타나지 않을 것입니다. 이를 해결하는 Selenium 구현 방식은 `community-contributions` 폴더를 참조해 주세요. Selenium 설치에 대해서는 별도의 학습이 필요합니다 (도움이 필요하면 저에게 물어보세요!).
#
# 또한 CloudFront(또는 유사한 서비스)로 보호되는 웹사이트는 403 에러를 뱉을 수 있습니다. 이 점을 지적해 주신 Andy J님께 감사의 말씀을 전합니다.
#
# 하지만 여전히 많은 웹사이트들은 문제없이 잘 작동할 것입니다!

# %%
display_summary("https://cnn.com")
# Out:
# CNN 웹사이트 요약:
# 글로벌 뉴스의 종합 선물세트! 미국 정치, 전 세계 소식, 비즈니스, 건강, 엔터테인먼트, 스포츠, 과학 등등 안 다루는 분야가 없어요. 심지어 광고 관련 피드백도 친절하게 받아주는 센스! 최신 속보부터 영상, 실시간 방송까지 한눈에 쏙쏙. 2026년 동계올림픽, 우크라이나-러시아 전쟁, 이스라엘-하마스 분쟁 같은 뜨거운 뉴스도 빼먹지 않고 다루니, 세상 돌아가는 거 궁금하면 여기만 보면 끝!
#
# 요약: 뉴스 덕후를 위한 만능 멀티탭, CNN. 재밌는 광고 클레임까지 접수하는 꼼꼼함은 덤.

# %%
display_summary("https://anthropic.com")
# Out:
# Anthropic 웹사이트 요약:
#
# "안쓰면 손해"급 AI 연구 회사가 심각하게 안전을 챙기면서 만든 AI들(Claude 시리즈)을 자랑하고 있습니다. 화성에서 AI가 운전까지 해버린 시대라니, 미래가 벌써 와버린 느낌. 광고도 스폰서도 없고 오로지 똑똑한 대화만 제공한다니, 광고 알레르기 있는 사람들에겐 천국. 최신 소식으로는 2026년 2월 5일에 세계 최강 코딩 및 전문 작업용 AI 모델 'Claude Opus 4.6'을 발표했다고 하네요. 안전과 신뢰를 핵심으로 AI 미래를 책임진다는 다짐도 잊지 않는, AI계의 착한 아이.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">비즈니스 활용 사례</h2>
#             <span style="color:#181;">이번 연습에서 여러분은 처음으로 프론티어 모델(AI 기술의 최전선에 있는 선도적인 모델)의 클라우드 API를 호출해 보았습니다. 우리는 이 과정에서 자체 LLM을 구축하는 것 외에도 OpenAI와 같은 API를 여러 단계에서 사용하게 될 것입니다.
#             <br/><br/>
#             좀 더 구체적으로, 우리는 이를 '요약(Summarization)'에 적용해 보았습니다. 요약은 생성형 AI의 가장 고전적인 활용 사례 중 하나입니다. 뉴스 요약, 재무 실적 요약, 자기소개서의 이력서 요약 등 모든 비즈니스 수직 계열에 적용될 수 있으며 그 활용 분야는 무궁무진합니다. 여러분의 비즈니스에 요약을 어떻게 적용할 수 있을지 고민해 보고, 솔루션 프로토타입을 직접 만들어 보세요.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">계속하기 전에 - 직접 시도해 보세요</h2>
#             <span style="color:#900;">아래 셀을 사용하여 여러분만의 간단한 상업적 예시를 만들어 보세요. 일단은 '요약' 활용 사례를 그대로 유지해 봅시다. 한 가지 아이디어를 드리자면, 이메일 본문을 가져와서 그에 적절하고 짧은 이메일 제목을 제안하는 기능을 작성해 보세요. 이는 실제 상용 이메일 도구에 탑재될 법한 유용한 기능입니다.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "something here"
user_prompt = """
    Lots of text
    Can be pasted here
"""

# Step 2: Make the messages list

messages = [] # fill this in

# Step 3: Call OpenAI
# response =

# Step 4: print the result
# print(

# %% [markdown]
# ## 웹 스크래핑을 즐기는 분들을 위한 추가 연습 문제
#
# `display_summary("https://openai.com")`을 실행해 보면 제대로 작동하지 않는다는 것을 알 수 있습니다! 그 이유는 OpenAI가 자바스크립트를 사용하는 화려한 웹사이트를 가지고 있기 때문입니다. 이미 알고 계신 분들도 있겠지만, 이를 해결할 수 있는 방법은 많습니다. 예를 들어, **Selenium**은 백그라운드에서 브라우저를 실제로 실행하고 페이지를 렌더링하여 쿼리할 수 있게 해주는 매우 인기 있는 프레임워크입니다.
#
# 만약 여러분이 Selenium, Playwright 또는 이와 유사한 도구에 경험이 있다면, `Website` 클래스가 이들을 사용하도록 직접 개선해 보세요. `community-contributions` 폴더에는 이전 수강생이 작성한 Selenium 해결 예시가 포함되어 있습니다(제공해 주셔서 감사합니다!).

# %% [markdown]
# # 코드 공유하기
#
# 여러분이 작성한 코드를 공유해 주시면 다른 분들과 함께 나눌 수 있어 정말 기쁠 것 같습니다! 이미 일부 수강생들이 변경 사항(Selenium 구현 포함)을 제안해 주셨고, 이는 `community-contributions` 폴더에서 확인하실 수 있습니다. 만약 여러분의 개선 사항을 해당 폴더에 추가하고 싶다면, 새로운 버전의 파일을 담아 **Pull Request(PR)**를 보내주세요. 확인 후 제가 병합(Merge)하도록 하겠습니다.
#
# 만약 git 사용이 익숙하지 않으시더라도 걱정 마세요(저도 전문가는 아닙니다!). 가이드 폴더의 **Guide 3**에 자세한 지침을 적어두었으며, 주요 내용을 여기에 옮겨왔습니다.
#
# PR을 생성하는 전체 단계와 주요 지침은 다음 링크에서 확인하실 수 있습니다:
# https://edwarddonner.com/pr
#
# 제출 전 다음 사항을 꼭 확인해 주세요:
# 1. (별도 논의가 없었다면) PR은 오직 `community-contributions` 폴더 내의 변경 사항만 포함해야 합니다.
# 2. 모든 노트북의 **실행 결과(Output)가 삭제된 상태**여야 합니다. (Clear all outputs)
# 3. 전체 코드 줄 수가 2,000줄 미만이어야 하며, 파일 수가 너무 많지 않아야 합니다.
# 4. 불필요한 테스트 파일, 너무 장황한 README, `.env.example`, 이모지 또는 기타 LLM이 생성한 부산물을 포함하지 마세요!
#
# 함께 참여해 주셔서 정말 감사합니다!
#
# 상세한 단계는 아래 링크를 참조하세요:
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
