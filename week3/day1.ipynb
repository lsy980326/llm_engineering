# %% [markdown]
# # Colab 소개
#
# Google Colab을 알아보고, (아직 없다면) Google 계정을 만드세요. [여기](https://colab.research.google.com/)
#
# 강의의 모든 프로젝트는 무료 티어나 소액만으로 진행할 수 있습니다. Colab Pro+를 쓰면 더 좋지만 필수는 아닙니다.
#
# Colab이 뭘 할 수 있는지 아래 링크에서 확인해 보세요!
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing
