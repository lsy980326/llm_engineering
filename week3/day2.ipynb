# %% [markdown]
# # HuggingFace pipelines
#
# 이번에는 Google Colab으로 이동해, HuggingFace 고수준 API인 **pipelines**를 다룹니다.
#
# https://colab.research.google.com/drive/1aMaEw8A56xs0bRM4lu8z7ou18jqyybGm?usp=sharing
#
# 이 노트북은 저비용(또는 무료) T4 GPU 런타임으로 실행할 수 있고, 결과도 잘 나옵니다!
#
# 노트북 안에 HuggingFace Token 설정 및 시크릿으로 넣는 방법이 안내되어 있습니다.
